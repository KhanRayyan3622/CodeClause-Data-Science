# %% [markdown]
# # Installing Libraies and Setting Environment

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('IMDB_reviews.csv')
df
# Out:
#                                                      URL  \
# 0      https://www.imdb.com/title/tt0137523/?ref_=ttl...
# 1      https://www.imdb.com/title/tt0137523/?ref_=ttl...
# 2      https://www.imdb.com/title/tt0137523/?ref_=ttl...
# 3      https://www.imdb.com/title/tt0137523/?ref_=ttl...
# 4      https://www.imdb.com/title/tt0137523/?ref_=ttl...
# ...                                                  ...
# 76388  https://www.imdb.com/title/tt0056687/?ref_=ttl...
# 76389  https://www.imdb.com/title/tt0056687/?ref_=ttl...
# 76390  https://www.imdb.com/title/tt0056687/?ref_=ttl...
# 76391  https://www.imdb.com/title/tt0056687/?ref_=ttl...
# 76392  https://www.imdb.com/title/tt0056687/?ref_=ttl...
#
#                                  Title  Release Year  \
# 0                           Fight Club          1999
# 1                           Fight Club          1999
# 2                           Fight Club          1999
# 3                           Fight Club          1999
# 4                           Fight Club          1999
# ...                                ...           ...
# 76388  What Ever Happened to Baby Jane          1962
# 76389  What Ever Happened to Baby Jane          1962
# 76390  What Ever Happened to Baby Jane          1962
# 76391  What Ever Happened to Baby Jane          1962
# 76392  What Ever Happened to Baby Jane          1962
#
#                                                   Poster  \
# 0      https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 1      https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 2      https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 3      https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 4      https://m.media-amazon.com/images/M/MV5BMmEzNT...
# ...                                                  ...
# 76388  https://m.media-amazon.com/images/M/MV5BZmI0M2...
# 76389  https://m.media-amazon.com/images/M/MV5BZmI0M2...
# 76390  https://m.media-amazon.com/images/M/MV5BZmI0M2...
# 76391  https://m.media-amazon.com/images/M/MV5BZmI0M2...
# 76392  https://m.media-amazon.com/images/M/MV5BZmI0M2...
#
#                          Genre        Director  \
# 0                        Drama   David Fincher
# 1                        Drama   David Fincher
# 2                        Drama   David Fincher
# 3                        Drama   David Fincher
# 4                        Drama   David Fincher
# ...                        ...             ...
# 76388  Drama, Horror, Thriller  Robert Aldrich
# 76389  Drama, Horror, Thriller  Robert Aldrich
# 76390  Drama, Horror, Thriller  Robert Aldrich
# 76391  Drama, Horror, Thriller  Robert Aldrich
# 76392  Drama, Horror, Thriller  Robert Aldrich
#
#                                                    Cast  Length  IMDB Rating  \
# 0           ['Brad Pitt', 'Edward Norton', 'Meat Loaf']  2h 19m          8.8
# 1           ['Brad Pitt', 'Edward Norton', 'Meat Loaf']  2h 19m          8.8
# 2           ['Brad Pitt', 'Edward Norton', 'Meat Loaf']  2h 19m          8.8
# 3           ['Brad Pitt', 'Edward Norton', 'Meat Loaf']  2h 19m          8.8
# 4           ['Brad Pitt', 'Edward Norton', 'Meat Loaf']  2h 19m          8.8
# ...                                                 ...     ...          ...
# 76388  ['Bette Davis', 'Joan Crawford', 'Victor Buono']  2h 14m          8.0
# 76389  ['Bette Davis', 'Joan Crawford', 'Victor Buono']  2h 14m          8.0
# 76390  ['Bette Davis', 'Joan Crawford', 'Victor Buono']  2h 14m          8.0
# 76391  ['Bette Davis', 'Joan Crawford', 'Victor Buono']  2h 14m          8.0
# 76392  ['Bette Davis', 'Joan Crawford', 'Victor Buono']  2h 14m          8.0
#
#        Metascore      Votes    Gross  \
# 0           67.0  2,267,031  $37.03M
# 1           67.0  2,267,031  $37.03M
# 2           67.0  2,267,031  $37.03M
# 3           67.0  2,267,031  $37.03M
# 4           67.0  2,267,031  $37.03M
# ...          ...        ...      ...
# 76388       75.0     60,552   $4.05M
# 76389       75.0     60,552   $4.05M
# 76390       75.0     60,552   $4.05M
# 76391       75.0     60,552   $4.05M
# 76392       75.0     60,552   $4.05M
#
#                                             Review Title  \
# 0            A great movie you can watch again and again
# 1                                                 Superb
# 2          Crazy, Cult, Plot Twist, Awesome = Fight Club
# 3                               Welcome to movie heaven!
# 4                                             Crazy good
# ...                                                  ...
# 76388                                     the two rivals
# 76389                                     milestone film
# 76390             A classic that has worn not so well...
# 76391              Whatever Happened To Baby Jane (1962)
# 76392   The downside of being a child star, and that ...
#
#                                              Review Text Rating By User  \
# 0      Because you'll probably be confused the first ...          10/10
# 1      Superb, and truly one of the greatest movies o...          10/10
# 2      I have no words about this film. This is maste...          10/10
# 3      Let's ignore the advice and talk about "Fight ...          10/10
# 4      So rewatchable. The acting is amazing, the sto...          10/10
# ...                                                  ...            ...
# 76388  what ever happened to baby  jane was a  good  ...            NaN
# 76389  Great movie, even though it was filmed in b&w,...          10/10
# 76390  This is still a must see movie for Bette Davis...           6/10
# 76391  I love this movie great character work by Craw...          10/10
# 76392  An original tale of jealousy, bitterness and r...           9/10
#
#              Review Date        Review Author
# 0       11 February 2020      Pukeonthestreet
# 1          19 April 2014              grantss
# 2           28 July 2021  jack_o_hasanov_imdb
# 3       16 December 2013          gogoschka-1
# 4        12 October 2019        trosati-98923
# ...                  ...                  ...
# 76388  29 September 2001        BETTEDAVISFAN
# 76389    13 January 2004         kelsodog2003
# 76390       22 July 2018    charliebeaglewoof
# 76391     18 August 2023         summerstager
# 76392     18 August 2023         tasmiyaahmed
#
# [76393 rows x 17 columns]

# %%
df.head()
# Out:
#                                                  URL       Title  \
# 0  https://www.imdb.com/title/tt0137523/?ref_=ttl...  Fight Club
# 1  https://www.imdb.com/title/tt0137523/?ref_=ttl...  Fight Club
# 2  https://www.imdb.com/title/tt0137523/?ref_=ttl...  Fight Club
# 3  https://www.imdb.com/title/tt0137523/?ref_=ttl...  Fight Club
# 4  https://www.imdb.com/title/tt0137523/?ref_=ttl...  Fight Club
#
#    Release Year                                             Poster  Genre  \
# 0          1999  https://m.media-amazon.com/images/M/MV5BMmEzNT...  Drama
# 1          1999  https://m.media-amazon.com/images/M/MV5BMmEzNT...  Drama
# 2          1999  https://m.media-amazon.com/images/M/MV5BMmEzNT...  Drama
# 3          1999  https://m.media-amazon.com/images/M/MV5BMmEzNT...  Drama
# 4          1999  https://m.media-amazon.com/images/M/MV5BMmEzNT...  Drama
#
#         Director                                         Cast  Length  \
# 0  David Fincher  ['Brad Pitt', 'Edward Norton', 'Meat Loaf']  2h 19m
# 1  David Fincher  ['Brad Pitt', 'Edward Norton', 'Meat Loaf']  2h 19m
# 2  David Fincher  ['Brad Pitt', 'Edward Norton', 'Meat Loaf']  2h 19m
# 3  David Fincher  ['Brad Pitt', 'Edward Norton', 'Meat Loaf']  2h 19m
# 4  David Fincher  ['Brad Pitt', 'Edward Norton', 'Meat Loaf']  2h 19m
#
#    IMDB Rating  Metascore      Votes    Gross  \
# 0          8.8       67.0  2,267,031  $37.03M
# 1          8.8       67.0  2,267,031  $37.03M
# 2          8.8       67.0  2,267,031  $37.03M
# 3          8.8       67.0  2,267,031  $37.03M
# 4          8.8       67.0  2,267,031  $37.03M
#
#                                      Review Title  \
# 0     A great movie you can watch again and again
# 1                                          Superb
# 2   Crazy, Cult, Plot Twist, Awesome = Fight Club
# 3                        Welcome to movie heaven!
# 4                                      Crazy good
#
#                                          Review Text Rating By User  \
# 0  Because you'll probably be confused the first ...          10/10
# 1  Superb, and truly one of the greatest movies o...          10/10
# 2  I have no words about this film. This is maste...          10/10
# 3  Let's ignore the advice and talk about "Fight ...          10/10
# 4  So rewatchable. The acting is amazing, the sto...          10/10
#
#         Review Date        Review Author
# 0  11 February 2020      Pukeonthestreet
# 1     19 April 2014              grantss
# 2      28 July 2021  jack_o_hasanov_imdb
# 3  16 December 2013          gogoschka-1
# 4   12 October 2019        trosati-98923

# %%
df.shape
# Out:
# (76393, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76393 entries, 0 to 76392
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   URL             76393 non-null  object
#  1   Title           76393 non-null  object
#  2   Release Year    76393 non-null  int64
#  3   Poster          76393 non-null  object
#  4   Genre           76393 non-null  object
#  5   Director        75474 non-null  object
#  6   Cast            75194 non-null  object
#  7   Length          75474 non-null  object
#  8   IMDB Rating     76393 non-null  float64
#  9   Metascore       75688 non-null  float64
#  10  Votes           76393 non-null  object
#  11  Gross           76393 non-null  object
#  12  Review Title    76393 non-null  object
#  13  Review Text     76393 non-null  object
#  14  Rating By User  68358 non-null  object
#  15  Review Date     76393 non-null  object
#  16  Review Author   76393 non-null  object
# dtypes: float64(2), int64(1), object(14)
# memory usage: 9.9+ MB

# %%
df.describe()
# Out:
#        Release Year   IMDB Rating     Metascore
# count  76393.000000  76393.000000  75688.000000
# mean    2000.770804      7.949838     78.410633
# std       13.992129      0.498210     11.392822
# min     1953.000000      6.500000     41.000000
# 25%     1997.000000      7.600000     72.000000
# 50%     2002.000000      7.900000     80.000000
# 75%     2011.000000      8.400000     87.000000
# max     2020.000000      9.300000     96.000000

# %%
for col in df.columns:
    temp = df[col].isnull().sum()
    if temp > 0:
        print(f'Column {col} contains {temp} null values')
# Out:
# Column Director contains 919 null values
# Column Cast contains 1199 null values
# Column Length contains 919 null values
# Column Metascore contains 705 null values
# Column Rating By User contains 8035 null values

# %%
# drop the irrelevant columns
df.drop(['Release Year', 'URL', 'Poster', 'Cast', 'Length'],
        axis=1,
        inplace=True)

# %%
df
# Out:
#                                  Title                    Genre  \
# 0                           Fight Club                    Drama
# 1                           Fight Club                    Drama
# 2                           Fight Club                    Drama
# 3                           Fight Club                    Drama
# 4                           Fight Club                    Drama
# ...                                ...                      ...
# 76388  What Ever Happened to Baby Jane  Drama, Horror, Thriller
# 76389  What Ever Happened to Baby Jane  Drama, Horror, Thriller
# 76390  What Ever Happened to Baby Jane  Drama, Horror, Thriller
# 76391  What Ever Happened to Baby Jane  Drama, Horror, Thriller
# 76392  What Ever Happened to Baby Jane  Drama, Horror, Thriller
#
#              Director  IMDB Rating  Metascore      Votes    Gross  \
# 0       David Fincher          8.8       67.0  2,267,031  $37.03M
# 1       David Fincher          8.8       67.0  2,267,031  $37.03M
# 2       David Fincher          8.8       67.0  2,267,031  $37.03M
# 3       David Fincher          8.8       67.0  2,267,031  $37.03M
# 4       David Fincher          8.8       67.0  2,267,031  $37.03M
# ...               ...          ...        ...        ...      ...
# 76388  Robert Aldrich          8.0       75.0     60,552   $4.05M
# 76389  Robert Aldrich          8.0       75.0     60,552   $4.05M
# 76390  Robert Aldrich          8.0       75.0     60,552   $4.05M
# 76391  Robert Aldrich          8.0       75.0     60,552   $4.05M
# 76392  Robert Aldrich          8.0       75.0     60,552   $4.05M
#
#                                             Review Title  \
# 0            A great movie you can watch again and again
# 1                                                 Superb
# 2          Crazy, Cult, Plot Twist, Awesome = Fight Club
# 3                               Welcome to movie heaven!
# 4                                             Crazy good
# ...                                                  ...
# 76388                                     the two rivals
# 76389                                     milestone film
# 76390             A classic that has worn not so well...
# 76391              Whatever Happened To Baby Jane (1962)
# 76392   The downside of being a child star, and that ...
#
#                                              Review Text Rating By User  \
# 0      Because you'll probably be confused the first ...          10/10
# 1      Superb, and truly one of the greatest movies o...          10/10
# 2      I have no words about this film. This is maste...          10/10
# 3      Let's ignore the advice and talk about "Fight ...          10/10
# 4      So rewatchable. The acting is amazing, the sto...          10/10
# ...                                                  ...            ...
# 76388  what ever happened to baby  jane was a  good  ...            NaN
# 76389  Great movie, even though it was filmed in b&w,...          10/10
# 76390  This is still a must see movie for Bette Davis...           6/10
# 76391  I love this movie great character work by Craw...          10/10
# 76392  An original tale of jealousy, bitterness and r...           9/10
#
#              Review Date        Review Author
# 0       11 February 2020      Pukeonthestreet
# 1          19 April 2014              grantss
# 2           28 July 2021  jack_o_hasanov_imdb
# 3       16 December 2013          gogoschka-1
# 4        12 October 2019        trosati-98923
# ...                  ...                  ...
# 76388  29 September 2001        BETTEDAVISFAN
# 76389    13 January 2004         kelsodog2003
# 76390       22 July 2018    charliebeaglewoof
# 76391     18 August 2023         summerstager
# 76392     18 August 2023         tasmiyaahmed
#
# [76393 rows x 12 columns]

# %%
df = df.dropna()
print("Total missing values: ", len(df))
# Out:
# Total missing values:  66998

# %%
df.nunique()
# Out:
# Title               101
# Genre                54
# Director             68
# IMDB Rating          23
# Metascore            38
# Votes               101
# Gross               101
# Review Title      59802
# Review Text       66982
# Rating By User       10
# Review Date        9120
# Review Author     45436
# dtype: int64

# %%
floats, objects = [], []
for col in df.columns:
    if df[col].dtype == object:
        objects.append(col)
    elif df[col].dtype == float:
        floats.append(col)
print(objects)
print(floats)
# Out:
# ['Title', 'Genre', 'Director', 'Votes', 'Gross', 'Review Title', 'Review Text', 'Rating By User', 'Review Date', 'Review Author']
# ['IMDB Rating', 'Metascore']

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Drama                           7423
# Drama, Horror, Mystery          4618
# Action, Sci-Fi                  3657
# Drama, Sci-Fi, Thriller         3234
# Crime, Drama, Thriller          3084
# Crime, Drama, Mystery           2915
# Mystery, Thriller               2861
# Drama, Mystery, Thriller        2421
# Crime, Thriller                 2404
# Action, Drama, Mystery          2108
# Crime, Drama                    2024
# Action, Drama, History          2006
# Drama, Mystery, Sci-Fi          1531
# Adventure, Drama, War           1471
# Drama, Western                  1464
# Action, Drama, Sci-Fi           1297
# Action, Drama                   1245
# Horror, Sci-Fi                  1178
# Horror, Mystery, Thriller       1175
# Comedy, Crime                   1071
# Drama, Mystery, War             1000
# Comedy, Drama                    961
# Drama, Romance, Sci-Fi           957
# Drama, Fantasy                   946
# Action, Crime, Mystery           902
# Comedy, Drama, Romance           873
# Biography, Drama, Sport          862
# Drama, Music                     796
# Action, Crime, Drama             780
# Drama, Thriller, War             678
# Comedy, Drama, Fantasy           625
# Adventure, Comedy, Fantasy       610
# Comedy, Fantasy, Mystery         581
# Adventure, Comedy, Drama         557
# Comedy                           545
# Drama, War                       539
# Drama, Horror                    526
# Drama, History, Thriller         513
# Action, Crime, Romance           469
# Drama, Thriller                  448
# Drama, Sci-Fi                    442
# Drama, Sport                     417
# Comedy, Crime, Drama             406
# Documentary, History, War        272
# Drama, Horror, Sci-Fi            269
# Biography, Drama, War            258
# Biography, Drama, History        255
# Animation, Adventure, Comedy     248
# Drama, Mystery, Romance          217
# Action, Sci-Fi, Thriller         203
# Drama, Horror, Thriller          190
# Adventure, Drama, Sci-Fi         172
# Comedy, Drama, Thriller          166
# Adventure, Drama, Thriller       128
# Name: count, dtype: int64

# %% [markdown]
# # Implementing K-Means Clustering

# %%
error = []
for n_clusters in range(1, 21):
    model = KMeans(init='k-means++',
                n_clusters=n_clusters,
                max_iter=500,
                random_state=22)
    model.fit(df)
    error.append(model.inertia_)
plt.figure(figsize=(10, 5))
sns.lineplot(x=range(1, 21), y=error)
sns.scatterplot(x=range(1, 21), y=error)
plt.show()

# %%
model = KMeans(init='k-means++',
            n_clusters=5,
            max_iter=500,
            random_state=22)
segments = model.fit_predict(df)
plt.figure(figsize=(7, 7))
sns.scatterplot(tsne_data[:, 0], tsne_data[:, 1], hue=segments)
plt.show()
